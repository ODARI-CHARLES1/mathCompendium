# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as scp
from matplotlib import colormaps
from sympy.abc import t,y
from sympy import dsolve,cos,Eq

# %% [markdown]
# $y'=cos(t)cos(y)$

# %%
_=np.linspace(-2*np.pi,2*np.pi,20)
T,Y=np.meshgrid(_,_)
Dy=np.cos(T)*np.cos(Y)
plt.quiver(T,Y,Dy)
plt.colorbar()
plt.title("Quiver plot of $y'=cos(t)cos(y)$")
plt.show()

# %%
#3d plot of y'
_=np.linspace(-2*np.pi,2*np.pi,2000)
T,Y=np.meshgrid(_,_)
Dy=np.cos(T)*np.cos(Y)
fig=plt.figure(figsize=(9,6))
ax=fig.add_subplot(projection="3d")
ax.plot_surface(T,Y,Dy,cmap="CMRmap_r")
plt.show()

# %%
#getting the solution of the differential equation using sympy
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[91], line 3
#       1 #getting the solution of the differential equation using sympy
#       2 dy=t
# ----> 3 dsolve(Eq(dy,0))
#
# File ~\.platformio\penv\Lib\site-packages\sympy\solvers\ode\ode.py:605, in dsolve(eq, func, hint, simplify, ics, xi, eta, x0, n, **kwargs)
#     602 given_hint = hint  # hint given by the user
#     604 # See the docstring of _desolve for more details.
# --> 605 hints = _desolve(eq, func=func,
#     606     hint=hint, simplify=True, xi=xi, eta=eta, type='ode', ics=ics,
#     607     x0=x0, n=n, **kwargs)
#     608 eq = hints.pop('eq', eq)
#     609 all_ = hints.pop('all', False)
#
# File ~\.platformio\penv\Lib\site-packages\sympy\solvers\deutils.py:180, in _desolve(eq, func, hint, ics, simplify, prep, **kwargs)
#     178 # preprocess the equation and find func if not given
# ...
