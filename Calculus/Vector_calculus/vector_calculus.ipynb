# %% [markdown]
# # Vector Geometry and Space.

# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

# Define points A and B
A = np.array([0, 0, 0])
B = np.array([3, 2, 5])

# Parametric line r(t) = A + t(B-A)
t = np.linspace(0, 1, 100)
line = A[:, None] + np.outer(B - A, t)

x = line[0]
y = line[1]
z = line[2]

# Plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.plot(x, y, z)
ax.scatter(A[0], A[1], A[2])
ax.scatter(B[0], B[1], B[2])

ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")

plt.show()

# %% [markdown]
# # Vector Geometry and Space

# %%
_=np.linspace(-4,4,1000)
x,y=_,_

# %%
X,Y=np.meshgrid(x,y)

# %%
a=[0,1,2];
b=[2,3,4];
np.outer(a,b)
# Out:
# array([[0, 0, 0],
#        [2, 3, 4],
#        [4, 6, 8]])

# %% [markdown]
# ## Equation of a plane
#
# $ax+bx+cx+d=0$
#
# where:
#
# $<a,b,c>$
#
# is the unit vector of the normal vector

# %%
import numpy as np
import matplotlib.pyplot as plt

# Plane coefficients
a, b, c, d =2, 3, 4, -12   # example: x + 2y + 3z - 6 = 0

# Create grid for x and y
x = np.linspace(-50, 5, 50)
y = np.linspace(-50, 5, 50)
X, Y = np.meshgrid(x, y)

# Solve for Z
Z = (-a*X - b*Y - d) / c

# Plot
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.plot_surface(X, Y, Z, alpha=1)

ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")

plt.show()

# %%
X.shape
# Out:
# (50, 50)

# %% [markdown]
# ## Plotting of Cylinder and Quadric Surfaces
# ![image.png](attachment:544887ab-3f84-42be-8761-50c71f4d4b70.png)
#
# Cylinder: $x^2+y^2=1$ on the z axis
#
# Parabolic: $z=x^2$

# %%
_=np.linspace(-5,5,1000)
X,Y=np.meshgrid(_,_)


Z=X**2;
fig,ax=plt.subplots(subplot_kw={"projection":"3d"})
ax.plot_surface(X,Y,Z)
#ax.view_init(0,45,0)

# %% [markdown]
# # Plotting a parabolic
#
# $z=x^2+y^2-9$

# %%
_=np.linspace(-5,5,100)
x,y=np.meshgrid(_,_)
Z=X**2+Y**2-9

fig,ax=plt.subplots(subplot_kw={"projection":"3d"})
#ax.plot_surface(X,Y,Z)
ax.plot_wireframe(X,Y,Z)

# %% [markdown]
# ## Plotting cylinder
#
# $x^2+y^2=9$
#
# use parametric to plot the cylinder
#
# $x=rcos(\theta)$
#
# $y=rsin(\theta)$
#
# z=z

# %%
r=3 #radius
h=5 #height

theta=np.linspace(0,2*np.pi,100)
z=np.linspace(0,5,100)

#meshgrid
theta_grid,z_grid=np.meshgrid(theta,z)

#parametric equations
X=np.cos(theta_grid)
Y=np.sin(theta_grid)
Z=z_grid

#plotting
ax.plot_surface(X,Y,Z)

# %% [markdown]
# ## Quadric Surfaces
#
# A quadric surfaceis the graph of a second-degree equation in three variables x, y, and z.
# The most general such equation is:
#
# $ Ax^2+By^2+Cz^2+Dxy+Eyz+Fxz+Gx+Hy+Iz+J=0 $
#
# where , , are constants, but by translation and rotation it can be brought into one
# of the two standard forms
#
# - $Ax^2+By^2+Cz^2+J=0$
#
# - $Ax^2+By^2+Cz+J=0$
#
# Examples:
#
# - Sphere
# - Ellipsoid
# - Hyperboloid
# - Paraboloid
# - Cone

# %%
_=np.linspace(-5,5,1000)
x,y=np.meshgrid(_,_)

# %% [markdown]
# ## 1. Elliptic Paraboloid
#
# $z=4x^2+y^2$

# %%
z=4*x**2+y**2
ax.plot_surface(x,y,z)
