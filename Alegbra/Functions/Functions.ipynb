# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt
import warnings 
import os
import pathlib
import scienceplots

warnings.filterwarnings("ignore")
plt.style.use(["science","no-latex"])

# %% [markdown]
# # Functions
#
# Functions can be classified into
#
# **LIATEC**
#
# - L-Logarithmic
# - I-Inverse Functions
# - A-Alegbraic Functions
# - T-Trigonometric
# - E-Exponential
# - C-Constant

# %% [markdown]
#  # 1. Logarithms

# %% [markdown]
# ## Definition
# $ a^x = N \;\Rightarrow\; \log_a(N) = x $
#
# ---
#
# ## Types
# - Common log: $ \log(x) = \log_{10}(x) $
# - Natural log: $ \ln(x) = \log_e(x) $
#
# ---
#
# ## Core Properties
#
# $ \log_a(xy) = \log_a(x) + \log_a(y) $
#
# $ \log_a\left(\frac{x}{y}\right) = \log_a(x) - \log_a(y) $
#
# $ \log_a(x^k) = k\log_a(x) $
#
# ---
#
# ## Change of Base
#
# $ \log_a(x) = \frac{\log_b(x)}{\log_b(a)} $
#
# ---
#
# ## Key Facts
# - Domain: $ x > 0 $
# - $ \log_a(1) = 0 $
# - Inverse relationship: $ a^x \leftrightarrow \log_a(x) $
#
# ---
#
# ## Applications
# - Signal processing (dB scale)
# - Control systems (Bode plots)
# - Algorithms (logarithmic complexity)

# %%
from sympy.abc import x
a,b=sp.symbols('a,b',positive=True)

# %%
f=sp.log(a,10)+sp.log(b,10)

# %%
sp.simplify(f)
# Out:
# (log(a) + log(b))/log(10)

# %%
g=sp.simplify(sp.log(a*b,10))

# %%
sp.expand_log(g)
# Out:
# (log(a) + log(b))/log(10)

# %%
#log(a^b)=blog(a)

sp.expand_log(sp.log(a**2))
# Out:
# 2*log(a)

# %%
sp.expand_log(sp.log(a/b))
# Out:
# log(a) - log(b)

# %%
#plotting a ln(x) function
sp.plot(sp.log(x))
plt.show()
